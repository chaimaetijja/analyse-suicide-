# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("who_suicide_statistics.csv")

# %%
df.describe()
# Out:
#                year   suicides_no    population
# count  43776.000000  41520.000000  3.831600e+04
# mean    1998.502467    193.315390  1.664091e+06
# std       10.338711    800.589926  3.647231e+06
# min     1979.000000      0.000000  2.590000e+02
# 25%     1990.000000      1.000000  8.511275e+04
# 50%     1999.000000     14.000000  3.806550e+05
# 75%     2007.000000     91.000000  1.305698e+06
# max     2016.000000  22338.000000  4.380521e+07

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population
# 0  Albania  1985  female  15-24 years          NaN    277900.0
# 1  Albania  1985  female  25-34 years          NaN    246800.0
# 2  Albania  1985  female  35-54 years          NaN    267500.0
# 3  Albania  1985  female   5-14 years          NaN    298300.0
# 4  Albania  1985  female  55-74 years          NaN    138700.0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["country"]
# Out:
# 0                     Albania
# 1                     Albania
# 2                     Albania
# 3                     Albania
# 4                     Albania
# 5                     Albania
# 6                     Albania
# 7                     Albania
# 8                     Albania
# 9                     Albania
# 10                    Albania
# 11                    Albania
# 12                    Albania
# 13                    Albania
# 14                    Albania
# 15                    Albania
# 16                    Albania
# 17                    Albania
# 18                    Albania
# 19                    Albania
# 20                    Albania
# 21                    Albania
# 22                    Albania
# 23                    Albania
# 24                    Albania
# 25                    Albania
# 26                    Albania
# 27                    Albania
# 28                    Albania
# 29                    Albania
#                  ...
# ...

# %%
type(df["country"])
# Out:
# pandas.core.series.Series

# %%
df_bis=df.iloc[20:100, :]

# %%
df_bis
# Out:
#     country  year     sex          age  suicides_no  population
# 20  Albania  1986    male  35-54 years          NaN    302000.0
# 21  Albania  1986    male   5-14 years          NaN    331600.0
# 22  Albania  1986    male  55-74 years          NaN    134800.0
# 23  Albania  1986    male    75+ years          NaN     21400.0
# 24  Albania  1987  female  15-24 years         14.0    289700.0
# 25  Albania  1987  female  25-34 years          4.0    257200.0
# 26  Albania  1987  female  35-54 years          6.0    278800.0
# 27  Albania  1987  female   5-14 years          0.0    311000.0
# 28  Albania  1987  female  55-74 years          0.0    144600.0
# 29  Albania  1987  female    75+ years          1.0     35600.0
# 30  Albania  1987    male  15-24 years         21.0    312900.0
# 31  Albania  1987    male  25-34 years          9.0    274300.0
# 32  Albania  1987    male  35-54 years         16.0    308000.0
# 33  Albania  1987    male   5-14 years          0.0    338200.0
# ...

# %%
df_bis= df.iloc[20:100 , 0:3]

# %%
df_bis
# Out:
#     country  year     sex
# 20  Albania  1986    male
# 21  Albania  1986    male
# 22  Albania  1986    male
# 23  Albania  1986    male
# 24  Albania  1987  female
# 25  Albania  1987  female
# 26  Albania  1987  female
# 27  Albania  1987  female
# 28  Albania  1987  female
# 29  Albania  1987  female
# 30  Albania  1987    male
# 31  Albania  1987    male
# 32  Albania  1987    male
# 33  Albania  1987    male
# 34  Albania  1987    male
# 35  Albania  1987    male
# 36  Albania  1988  female
# 37  Albania  1988  female
# 38  Albania  1988  female
# 39  Albania  1988  female
# 40  Albania  1988  female
# 41  Albania  1988  female
# 42  Albania  1988    male
# 43  Albania  1988    male
# 44  Albania  1988    male
# 45  Albania  1988    male
# 46  Albania  1988    male
# 47  Albania  1988    male
# 48  Albania  1989  female
# 49  Albania  1989  female
# ..      ...   ...     ...
# 70  Albania  1990    male
# 71  Albania  1990    male
# 72  Albania  1991  female
# ...

# %%
df_maroc = df[df["country"] == "Morocco"]

# %%
df_maroc.head(3)
# Out:
#        country  year     sex          age  suicides_no  population
# 26304  Morocco  2000  female  15-24 years          0.0         NaN
# 26305  Morocco  2000  female  25-34 years          2.0         NaN
# 26306  Morocco  2000  female  35-54 years          3.0         NaN

# %%
df_1998=df[df["year"] == 1993]

# %%
df_1998
# Out:
#                                   country  year     sex          age  \
# 96                                Albania  1993  female  15-24 years
# 97                                Albania  1993  female  25-34 years
# 98                                Albania  1993  female  35-54 years
# 99                                Albania  1993  female   5-14 years
# 100                               Albania  1993  female  55-74 years
# 101                               Albania  1993  female    75+ years
# 102                               Albania  1993    male  15-24 years
# 103                               Albania  1993    male  25-34 years
# 104                               Albania  1993    male  35-54 years
# 105                               Albania  1993    male   5-14 years
# 106                               Albania  1993    male  55-74 years
# 107                               Albania  1993    male    75+ years
# 492                              Anguilla  1993  female  15-24 years
# ...

# %%
df_Albania=df[(df["country"] == "Albania") & (df["year"] == 1993)]

# %%
df_Albania
# Out:
#      country  year     sex          age  suicides_no  population
# 96   Albania  1993  female  15-24 years         10.0    285300.0
# 97   Albania  1993  female  25-34 years          7.0    261800.0
# 98   Albania  1993  female  35-54 years          7.0    331200.0
# 99   Albania  1993  female   5-14 years          1.0    340300.0
# 100  Albania  1993  female  55-74 years          2.0    169500.0
# 101  Albania  1993  female    75+ years          0.0     39300.0
# 102  Albania  1993    male  15-24 years         18.0    243300.0
# 103  Albania  1993    male  25-34 years          9.0    230100.0
# 104  Albania  1993    male  35-54 years         10.0    350300.0
# 105  Albania  1993    male   5-14 years          1.0    367000.0
# 106  Albania  1993    male  55-74 years          7.0    165000.0
# 107  Albania  1993    male    75+ years          1.0     24200.0

# %%
sns.barplot(x=df["sex"] , y=df["suicides_no"])
# Out:
# C:\Users\Poste\Anaconda2\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x=df["age"] , y=df["suicides_no"])

# %%
df_homme=df[df["sex"]=="male"]

# %%
df_homme
# Out:
#                     country  year   sex          age  suicides_no  population
# 6                   Albania  1985  male  15-24 years          NaN    301400.0
# 7                   Albania  1985  male  25-34 years          NaN    264200.0
# 8                   Albania  1985  male  35-54 years          NaN    296700.0
# 9                   Albania  1985  male   5-14 years          NaN    325800.0
# 10                  Albania  1985  male  55-74 years          NaN    132500.0
# 11                  Albania  1985  male    75+ years          NaN     21100.0
# 18                  Albania  1986  male  15-24 years          NaN    306700.0
# 19                  Albania  1986  male  25-34 years          NaN    269000.0
# 20                  Albania  1986  male  35-54 years          NaN    302000.0
# 21                  Albania  1986  male   5-14 years          NaN    331600.0
# 22                  Albania  1986  male  55-74 years          NaN    134800.0
# ...

# %%
sns.barplot(x=df_homme["age"] , y=df_homme["suicides_no"])

# %%
df_femme=df[df["sex"]=="female"]

# %%
df_femme
# Out:
#                     country  year     sex          age  suicides_no  \
# 0                   Albania  1985  female  15-24 years          NaN
# 1                   Albania  1985  female  25-34 years          NaN
# 2                   Albania  1985  female  35-54 years          NaN
# 3                   Albania  1985  female   5-14 years          NaN
# 4                   Albania  1985  female  55-74 years          NaN
# 5                   Albania  1985  female    75+ years          NaN
# 12                  Albania  1986  female  15-24 years          NaN
# 13                  Albania  1986  female  25-34 years          NaN
# 14                  Albania  1986  female  35-54 years          NaN
# 15                  Albania  1986  female   5-14 years          NaN
# 16                  Albania  1986  female  55-74 years          NaN
# 17                  Albania  1986  female    75+ years          NaN
# 24                  Albania  1987  female  15-24 years         14.0
# ...

# %%
sns.barplot(data=df_femme, x="age", y="suicides_no", estimator = sum)

# %%
sns.factorplot(data = df, x="age", y="suicides_no", hue="sex", kind ="bar")
# Out:
# C:\Users\Poste\Anaconda2\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(data = df, x="age", y="suicides_no", hue="sex", kind="violin")
# Out:
# C:\Users\Poste\Anaconda2\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of                     country  year     sex          age  suicides_no  \
# 0                   Albania  1985  female  15-24 years          NaN
# 1                   Albania  1985  female  25-34 years          NaN
# 2                   Albania  1985  female  35-54 years          NaN
# 3                   Albania  1985  female   5-14 years          NaN
# 4                   Albania  1985  female  55-74 years          NaN
# 5                   Albania  1985  female    75+ years          NaN
# 6                   Albania  1985    male  15-24 years          NaN
# 7                   Albania  1985    male  25-34 years          NaN
# 8                   Albania  1985    male  35-54 years          NaN
# 9                   Albania  1985    male   5-14 years          NaN
# 10                  Albania  1985    male  55-74 years          NaN
# 11                  Albania  1985    male    75+ years          NaN
# ...

# %%
df_pays=df[['country','suicides_no']].groupby("country").sum()

# %%
df_pays.head()
# Out:
#                      suicides_no
# country
# Albania                   1970.0
# Anguilla                     2.0
# Antigua and Barbuda         11.0
# Argentina                93862.0
# Armenia                   2422.0

# %%
df_pays_sorted=df_pays.sort_values("suicides_no")

# %%
df_pays_sorted
# Out:
#                                 suicides_no
# country
# Montserrat                              1.0
# Falkland Islands (Malvinas)             1.0
# Anguilla                                2.0
# Iraq                                    3.0
# Sao Tome and Principe                   4.0
# Saint Pierre and Miquelon               5.0
# Turks and Caicos Islands                6.0
# Mayotte                                 6.0
# British Virgin Islands                  8.0
# Antigua and Barbuda                    11.0
# Monaco                                 17.0
# Cayman Islands                         19.0
# Maldives                               20.0
# Saint Kitts and Nevis                  25.0
# San Marino                             26.0
# Macau                                  27.0
# Haiti                                  28.0
# Tunisia                                32.0
# Oman                                   33.0
# Grenada                                38.0
# ...

# %%
df_pays_to_plot=df_pays_sorted.reset_index()

# %%
df_pays_to_plot
# Out:
#                             country  suicides_no
# 0                        Montserrat          1.0
# 1       Falkland Islands (Malvinas)          1.0
# 2                          Anguilla          2.0
# 3                              Iraq          3.0
# 4             Sao Tome and Principe          4.0
# 5         Saint Pierre and Miquelon          5.0
# 6          Turks and Caicos Islands          6.0
# 7                           Mayotte          6.0
# 8            British Virgin Islands          8.0
# 9               Antigua and Barbuda         11.0
# 10                           Monaco         17.0
# 11                   Cayman Islands         19.0
# 12                         Maldives         20.0
# 13            Saint Kitts and Nevis         25.0
# 14                       San Marino         26.0
# 15                            Macau         27.0
# 16                            Haiti         28.0
# 17                          Tunisia         32.0
# ...

# %%
plt=sns.barplot(data=df_pays_to_plot.tail(7) , x="country" , y="suicides_no")
plt.set_xticklabels(plt.get_xticklabels(), rotation=90)
# Out:
# [Text(0,0,'Republic of Korea'),
#  Text(0,0,'Germany'),
#  Text(0,0,'Ukraine'),
#  Text(0,0,'France'),
#  Text(0,0,'Japan'),
#  Text(0,0,'United States of America'),
#  Text(0,0,'Russian Federation')]
